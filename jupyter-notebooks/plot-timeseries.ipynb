# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

from pandas import *
from pandas.io.parsers import read_csv

# %%
ral = read_csv('ral5aod.csv', index_col=False, header=None,
               names=['timestamp','host','size','duration'],
               usecols=['timestamp', 'duration'])
ral['timestamp'] = pd.to_datetime(ral['timestamp'],unit='s')
#starttime = min(df['timestamp'])
ral.set_index('timestamp', inplace=True)
ral.plot()

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ral['duration'].plot.hist(bins=100,alpha=0.8)
#bnl.hist(ax=ax, bins=bins, label=['bnl'], alpha=0.5)
ax.set(title='Distribution of write duration', xlabel='Duration (s)', ylabel='Count')
ax.legend().set_visible(True)
